# %%
import pandas as pd
parkings = pd.read_csv("parking-paris.csv")
parkings.drop(["H_PARC_CM", "H2_PARC_CM", "TYPE_PARC", "HORAIRE_NA", "ASC_SURF"], axis=1, inplace=True)
parkings.drop(["ABMOTO_1AE", "TVELO_1M_E", "TVELO_1M_E", "POINT_X", "POINT_Y", "ZONES_RES", "TF_15MN_MO"], axis=1, inplace=True)
parkings.drop(["OBJECTID", "ADRESS_SSC", "ACCES_VL", "DELEG", "SITE_DELEG"], axis=1, inplace=True)
parkings.drop(["TF_24H_MOT", "TF_PR_MOTO", "PR_1A_MINM", "PR_1A_MAXM", "TF_RES_MO", "TF_RES_1AM", "AB_1A_PATT"], axis=1, inplace=True)
parkings.drop(["ACCES_MOTO","V_ELEC_CH", "AUTOPART", "DATE_TA", "ABVE_1T_E", "ABVE_1A_E"], axis=1, inplace=True)
parkings.drop(["NB_PL_MOTO", "TMOTO_1EHE","ABMOTO_1ME", "ABMOTO_1TE", "TF_30MN_MO", "PARC_AMOD"], axis=1, inplace=True)
parkings.drop(["TF_12H_E", "TF_24H_E", "NB_PL_PMR", "ABPMR_1M_E", 	"ABPMR_1T_E","ABPMR_1A_E",	"MIS_A_JOUR",	"ABVE_1M_E"], axis=1, inplace=True)
parkings.drop(["TF_2H_E","TF_3H_E",	"TF_4H_E",	"TF_7H_E",	"TF_8H_E",	"TF_9H_E",	"TF_10H_E",	"TF_11H_E"], axis=1, inplace=True)
parkings.drop(["PR_1A_MINE","PR_1A_MAXE","TARIF_RES","TF_RES_1AE","DATE_TH","TF_15MN_E","TF_30MN_E","TF_1H_E","TF_1H30_E"], axis=1, inplace=True)
parkings.drop(["ACCES_VELO","AB_1M_E","AB_1A_E","TARIF_PR", "geo_shape"], axis=1, inplace=True)
parkings.head(10)
parkings.to_csv("new_parking.csv", index=False, encoding='utf8')

# %%
import pandas as pd
weather = pd.read_csv("export-paris2017.csv")
weather2017 = weather.loc[:,['DATE','PRECIP_TOTAL_DAY_MM', 'VISIBILITY_AVG_KM']]
weather2017['DATE'] = pd.to_datetime(weather['DATE'], format = '%Y-%m-%d').dt.date
weather2017.head(10)
weather2017.to_csv("weather2018.csv")

# %%
newweathers = pd.read_csv("weather2017.csv")
newweathers.head(10)
# Out:
#    Unnamed: 0        DATE  PRECIP_TOTAL_DAY_MM  VISIBILITY_AVG_KM
# 0           0  2017-01-01                  0.0             10.000
# 1           1  2017-01-02                  0.3              8.000
# 2           2  2017-01-03                  0.0              9.000
# 3           3  2017-01-04                  0.6              7.000
# 4           4  2017-01-05                  0.0              8.000
# 5           5  2017-01-06                  0.0             10.000
# 6           6  2017-01-07                  0.3              9.125
# 7           7  2017-01-08                  0.9              0.250
# 8           8  2017-01-09                  1.6              5.125
# 9           9  2017-01-10                  6.2              7.000

# %%
newweathers = pd.read_csv("weather2018.csv")
newweathers.head(10)
# Out:
#    Unnamed: 0        DATE  PRECIP_TOTAL_DAY_MM  VISIBILITY_AVG_KM
# 0           0  2017-01-01                  0.0             10.000
# 1           1  2017-01-02                  0.3              8.000
# 2           2  2017-01-03                  0.0              9.000
# 3           3  2017-01-04                  0.6              7.000
# 4           4  2017-01-05                  0.0              8.000
# 5           5  2017-01-06                  0.0             10.000
# 6           6  2017-01-07                  0.3              9.125
# 7           7  2017-01-08                  0.9              0.250
# 8           8  2017-01-09                  1.6              5.125
# 9           9  2017-01-10                  6.2              7.000

# %%
# def modif(x):
#     x = x.replace('7', '8', 1)
#     return x

# newweathers['DATE'] = newweathers['DATE'].apply(lambda x: modif(x))
# newweathers.head(10)
# Out:
#    Unnamed: 0        DATE  PRECIP_TOTAL_DAY_MM  VISIBILITY_AVG_KM
# 0           0  2018-01-01                  0.0             10.000
# 1           1  2018-01-02                  0.3              8.000
# 2           2  2018-01-03                  0.0              9.000
# 3           3  2018-01-04                  0.6              7.000
# 4           4  2018-01-05                  0.0              8.000
# 5           5  2018-01-06                  0.0             10.000
# 6           6  2018-01-07                  0.3              9.125
# 7           7  2018-01-08                  0.9              0.250
# 8           8  2018-01-09                  1.6              5.125
# 9           9  2018-01-10                  6.2              7.000

# %%
import pandas as pd
weather = pd.read_csv("export2018.csv")
weather2018 = weather.loc[:,['DATE','PRECIP_TOTAL_DAY_MM', 'VISIBILITY_AVG_KM']]
weather2018['DATE'] = pd.to_datetime(weather['DATE'], format = '%Y-%m-%d').dt.date
weather2018.head(10)
weather2018.to_csv("weather2018.csv")

# %%
newweathers = pd.read_csv("weather2018.csv")
newweathers.head(10)
# Out:
#    Unnamed: 0        DATE  PRECIP_TOTAL_DAY_MM  VISIBILITY_AVG_KM
# 0           0  2018-01-01                  0.0             10.000
# 1           1  2018-01-02                  0.3              8.000
# 2           2  2018-01-03                  0.0              9.000
# 3           3  2018-01-04                  0.6              7.000
# 4           4  2018-01-05                  0.0              8.000
# 5           5  2018-01-06                  0.0             10.000
# 6           6  2018-01-07                  0.3              9.125
# 7           7  2018-01-08                  0.9              0.250
# 8           8  2018-01-09                  1.6              5.125
# 9           9  2018-01-10                  6.2              7.000

# %%
newweathers.loc[newweathers['DATE']=='2018-08-04']
# Out:
#      Unnamed: 0        DATE  PRECIP_TOTAL_DAY_MM  VISIBILITY_AVG_KM
# 215         215  2018-08-04                  0.2              9.375

# %%
import pandas as pd
from datetime import datetime
start_date=datetime.strptime("2018-08-17", "%Y-%m-%d")
end_date=datetime.strptime("2018-08-20", "%Y-%m-%d")
df = pd.read_csv("bookings.csv")
df['dep_time']=pd.to_datetime(df['dep_time'])
mask = (df['dep_time'] > start_date) & (df['dep_time'] <= end_date)
data = df.loc[mask]
data
# Out:
#        id  client_id  departure_id  arrival_id            dep_time  \
# 7545    1        893           100          26 2018-08-17 00:19:00
# 7546    2       1647           128          17 2018-08-17 00:26:00
# 7547    3        237            78          49 2018-08-17 00:18:00
# 7548    4        496           150         159 2018-08-17 01:36:00
# 7549    5       1012           112         132 2018-08-17 01:14:00
# 7550    6       2199            63          39 2018-08-17 01:35:00
# 7551    7       2434             7         155 2018-08-17 01:47:00
# 7552    8       1654           128         120 2018-08-17 02:28:00
# 7553    9       2831           103           9 2018-08-17 02:18:00
# 7554   10       2301            62          73 2018-08-17 02:02:00
# 7555   11       1073           171          53 2018-08-17 02:28:00
# 7556   12        775           146          71 2018-08-17 03:49:00
# 7557   13       2552           152         109 2018-08-17 03:06:00
# ...

# %%
import pandas as pd
hist = pd.read_csv("yearHistoryTemplate.csv")
hist.shape
# Out:
# (177600, 10)

# %%
trafic01 = pd.read_csv("donnees_trafic_capteurs_201701.txt", sep='\t', error_bad_lines=False, header=None)
trafic01.columns=['id_arc_trafic', 'datetime', 'debit', 'taux']
#trafic01.loc[trafic01['id_arc_trafic']==500].shape
#trafic01.groupby(['id_arc_trafic']).agg(['count'])
trafic01 = trafic01[trafic01['taux'].notnull()]
trafic01 = trafic01[trafic01['debit'].notnull()]
#idtrafic = trafic01['id_arc_trafic'].unique().tolist()
#chunks = [idtrafic[x:x+100] for x in range(0, len(idtrafic), 100)]
# I decide to simplify my job, i calculate juste id arc = 1

# %%
# clean trafic data and add a id arc trafic to yearTemplatehisotry


import os
def cleanAllTrafics(folderName, idtrafics):
    files = os.listdir(folderName)
    res = pd.DataFrame(columns=['id_arc_trafic', 'datetime', 'debit', 'taux'])
    for name in files:
        print("handle file : " + name)
        trafic = pd.read_csv(folderName + "/" + name, sep='\t', error_bad_lines=False, header=None)
        trafic.columns = ['id_arc_trafic', 'datetime', 'debit', 'taux']
        traficAux = trafic.loc[trafic['id_arc_trafic'].isin(idtrafics)]
        res = pd.concat([res, traficAux], axis=0)
        print("current trafix length : " + str(traficAux.shape[0]) + " res length : " + str(res.shape[0]))
    print("finish")
    return res
        
res = cleanAllTrafics("./2017_paris_trafic_capteurs", [1])
res = res.reset_index(drop=True)
res.fillna(0, inplace=True)
res['taux'] = res['taux'].apply(lambda x: str(x).replace('"',....
# res.to_csv("2017-paris-trafic.csv")
res.head(10)
# Out:
# handle file : donnees_trafic_capteurs_201711.txt
# current trafix length : 720 res length : 720
# handle file : donnees_trafic_capteurs_201707.txt
# current trafix length : 744 res length : 1464
# handle file : donnees_trafic_capteurs_201703.txt
# current trafix length : 744 res length : 2208
# handle file : donnees_trafic_capteurs_201712.txt
# current trafix length : 768 res length : 2976
# handle file : donnees_trafic_capteurs_201710.txt
# current trafix length : 768 res length : 3744
# handle file : donnees_trafic_capteurs_201705.txt
# current trafix length : 744 res length : 4488
# handle file : donnees_trafic_capteurs_201704.txt
# current trafix length : 720 res length : 5208
# handle file : donnees_trafic_capteurs_201708.txt
# current trafix length : 744 res length : 5952
# handle file : donnees_trafic_capteurs_201706.txt
# current trafix length : 719 res length : 6671
# handle file : donnees_trafic_capteurs_201709.txt
# current trafix length : 720 res length : 7391
# ...

# %%
# Out:
#   id_arc_trafic             datetime debit taux
# 0           796  2017-11-01 01:00:00   126   ,4
# 1           796  2017-11-01 02:00:00    48   ,2
# 2           796  2017-11-01 03:00:00    48   ,2
# 3           796  2017-11-01 04:00:00    45   ,2
# 4           796  2017-11-01 05:00:00    30   ,1
# 5           796  2017-11-01 06:00:00    39   ,2
# 6           796  2017-11-01 07:00:00    49   ,2
# 7           796  2017-11-01 08:00:00    62   ,3
# 8           796  2017-11-01 09:00:00   128   ,6
# 9           796  2017-11-01 10:00:00   173   ,7
